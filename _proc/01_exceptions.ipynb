# %% [raw]
# ---
# output-file: exceptions.html
# title: Custom exceptions
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#|output: asis
#| echo: false
show_doc(ColumnFullError)
# Out:
# ---
#
# [source](https://github.com/Jorgvt/matatena/blob/main/matatena/exceptions.py#L7){target="_blank" style="float:right; font-size:smaller"}
#
# ### ColumnFullError
#
#
#
# Raised when trying to put a dice in a column that is already full.
