# %% [raw]
# ---
# description: '"Matatena (or Knucklebones in english) is a game played in the game
#   *Cult of the lamb*. Here we provied a Python implementation of the game with the
#   objective to be able to use it as a *gym* environment for reinforcement learning."'
# output-file: index.html
# title: matatena
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Install

# %% [markdown]
# ```sh
# pip install matatena
# ```
